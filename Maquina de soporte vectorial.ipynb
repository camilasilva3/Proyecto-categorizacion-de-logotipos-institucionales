# %% [markdown]
# ### **Librerias**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap
import re, seaborn as sns
from scipy.stats import normaltest
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multiclass import OneVsOneClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import preprocessing

# %% [markdown]
# ### **Preprocesamiento de datos**

# %%
archivo = 'C:/Users/camil/Desktop/TESIS/Datos/Prueba/Final.xlsx'
df = pd.read_excel(archivo, sheet_name='Hoja1')
df
# Out:
#       Page       Imagen Experiment   Code  Valence  Domain  Arousal
# 0        1  Carabineros        EX2  EX2-1      1.0     9.0      5.0
# 1        1  Carabineros        EX2  EX2-2      3.0     8.0      8.0
# 2        1  Carabineros        EX2  EX2-3      1.0     8.0      NaN
# 3        1  Carabineros        EX2  EX2-4      1.0     9.0      8.0
# 4        1  Carabineros        EX2  EX2-5      1.0     9.0      8.0
# ...    ...          ...        ...    ...      ...     ...      ...
# 8875    10         SHOA        EX1  EX1-4      5.0     9.0      9.0
# 8876    10         SHOA        EX1  EX1-5      6.0     9.0      9.0
# 8877    10         SHOA        EX1  EX1-6      3.0     7.0      7.0
# 8878    10         SHOA        EX1  EX1-7      4.0     7.0      8.0
# 8879    10         SHOA        EX1  EX1-8      6.0     9.0      9.0
#
# [8880 rows x 7 columns]

# %%
df.dtypes
# Out:
# Page            int64
# Imagen         object
# Experiment     object
# Code           object
# Valence       float64
# Domain        float64
# Arousal       float64
# dtype: object

# %% [markdown]
# #### Exploración de datos

# %%
sns.pairplot(df.drop(['Page', 'Experiment', 'Code'], axis = 1), hue='Imagen', height=2)

# %%
plt.rcParams["figure.figsize"] = (12,4)
plt.subplot(1,3,1)
var1 = 'Valence'
data1 = pd.concat([df['Imagen'], df[var1]], axis=1)
plt.scatter(x=data1[var1], y=data1['Imagen'], alpha = 0.5, c='r');
plt.xlabel('Valencia')

plt.subplot(1,3,2)
var2 = 'Domain'
data2 = pd.concat([df['Imagen'], df[var2]], axis=1)
plt.scatter(x=data2[var2], y=data2['Imagen'], alpha = 0.5, c='g');
plt.xlabel('Dominancia')

plt.subplot(1,3,3)
var3 = 'Arousal'
data3 = pd.concat([df['Imagen'], df[var3]], axis=1)
plt.scatter(x=data3[var3], y=data3['Imagen'], alpha = 0.5);
plt.xlabel('Activación')

plt.tight_layout()

# %%
import warnings
warnings.filterwarnings('ignore')
plot = sns.FacetGrid(df, hue="Imagen")
plot.map(sns.distplot, "Valence").add_legend()
plot = sns.FacetGrid(df, hue="Imagen")
plot.map(sns.distplot, "Domain").add_legend()
plot = sns.FacetGrid(df, hue="Imagen")
plot.map(sns.distplot, "Arousal").add_legend()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15,5))
axes[0].set_title("Valencia")
axes[0].hist(df['Valence'], bins=9, color='palevioletred', rwidth=0.85)
axes[0].set_xlabel('rango')
axes[0].set_ylabel('Frecuencia')
axes[1].set_title("Dominancia")
axes[1].hist(df['Domain'], bins=9,color='palevioletred', rwidth=0.85);
axes[1].set_xlabel('rango')
axes[1].set_ylabel('Frecuencia')
axes[2].set_title("Activación")
axes[2].hist(df['Arousal'], bins=9, color='palevioletred', rwidth=0.85);
axes[2].set_xlabel('rango')
axes[2].set_ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
stat1, p1 = normaltest(df['Valence'])
stat2, p2 = normaltest(df['Domain'])
stat3, p3 = normaltest(df['Arousal'])
# Test de Diagnostico Valencia 
print('VALENCIA:', 'Estadisticos=%.3f, p=%.3f' % (stat1, p1))
if p1 > 0.05: print('La muestra parece Gaussiana o Normal (no se rechaza la hipótesis nula H0)')
else: print('La muestra no parece Gaussiana o Normal(se rechaza la hipótesis nula H0)')
# Test de Diagnostico Valencia 
print('DOMINANCIA', 'Estadisticos=%.3f, p=%.3f' % (stat2, p2))
if p2 > 0.05: print('La muestra parece Gaussiana o Normal (no se rechaza la hipótesis nula H0)')
else: print('La muestra no parece Gaussiana o Normal(se rechaza la hipótesis nula H0)')
# Test de Diagnostico Valencia 
print('Activación', 'Estadisticos=%.3f, p=%.3f' % (stat3, p3))
if p3 > 0.05: print('La muestra parece Gaussiana o Normal (no se rechaza la hipótesis nula H0)')
else: print('La muestra no parece Gaussiana o Normal(se rechaza la hipótesis nula H0)')
# Out:
# VALENCIA: Estadisticos=nan, p=nan
# La muestra no parece Gaussiana o Normal(se rechaza la hipótesis nula H0)
# DOMINANCIA Estadisticos=nan, p=nan
# La muestra no parece Gaussiana o Normal(se rechaza la hipótesis nula H0)
# Activación Estadisticos=nan, p=nan
# La muestra no parece Gaussiana o Normal(se rechaza la hipótesis nula H0)

# %%
def graph(y):
    sns.boxplot(x="Imagen", y=y, data=df)
 
plt.figure(figsize=(20,10))
plt.subplot(311)
graph('Valence')
plt.subplot(312)
graph('Domain')
plt.subplot(313)
graph('Arousal')
plt.show()

# %% [markdown]
# #### Análisis de datos

# %%
df.describe()
# Out:
#               Page      Valence       Domain      Arousal
# count  8880.000000  8862.000000  8847.000000  8854.000000
# mean      5.500000     4.688671     5.330734     5.206122
# std       2.872443     2.865570     2.447649     2.626164
# min       1.000000     1.000000     1.000000     1.000000
# 25%       3.000000     2.000000     4.000000     3.000000
# 50%       5.500000     5.000000     5.000000     5.000000
# 75%       8.000000     7.000000     7.000000     8.000000
# max      10.000000     9.000000     9.000000     9.000000

# %%
corr_matrix = df.corr(method='pearson')
fig, ax = plt.subplots(nrows=1, ncols=1)
sns.heatmap(corr_matrix, annot = True, cbar = False, annot_kws = {"size": 12},vmin = -1, vmax = 1, center = 0, cmap = sns.cubehelix_palette(as_cmap=True),
    square = True,ax = ax,
            xticklabels=['Página','Valencia','Dominancia','Activación'],
            yticklabels=['Página','Valencia','Dominancia','Activación'], linewidths=0.7,linecolor="white")
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation = 45,
    horizontalalignment = 'right')
ax.tick_params(labelsize = 10)
plt.rcParams["figure.figsize"]=(12,5)

# %% [markdown]
# #### Limpieza de datos

# %%
total = df.isnull().sum().sort_values(ascending = False)
percent = (df.isnull().sum() / df.isnull().count()).sort_values(ascending = False)
missing_data = pd.concat([total, percent], axis = 1, keys = ['Total', 'Percent'])
missing_data.head(20)
# Out:
#             Total   Percent
# Domain         33  0.003716
# Arousal        26  0.002928
# Valence        18  0.002027
# Page            0  0.000000
# Imagen          0  0.000000
# Experiment      0  0.000000
# Code            0  0.000000

# %%
df = df.drop(df.loc[df['Valence'].isnull()].index)
df = df.drop(df.loc[df['Arousal'].isnull()].index)
df = df.drop(df.loc[df['Domain'].isnull()].index)
df.isnull().sum().max()
# Out:
# 0

# %%
print(f"Los datos duplicados son en total {df.duplicated().sum()}")
print(f"Los datos duplicados son {df.duplicated}")
df.drop_duplicates()
# Out:
# Los datos duplicados son en total 0
# Los datos duplicados son <bound method DataFrame.duplicated of       Page       Imagen Experiment   Code  Valence  Domain  Arousal
# 0        1  Carabineros        EX2  EX2-1      1.0     9.0      5.0
# 1        1  Carabineros        EX2  EX2-2      3.0     8.0      8.0
# 3        1  Carabineros        EX2  EX2-4      1.0     9.0      8.0
# 4        1  Carabineros        EX2  EX2-5      1.0     9.0      8.0
# 5        1  Carabineros        EX2  EX2-6      5.0     5.0      5.0
# ...    ...          ...        ...    ...      ...     ...      ...
# 8875    10         SHOA        EX1  EX1-4      5.0     9.0      9.0
# 8876    10         SHOA        EX1  EX1-5      6.0     9.0      9.0
# 8877    10         SHOA        EX1  EX1-6      3.0     7.0      7.0
# 8878    10         SHOA        EX1  EX1-7      4.0     7.0      8.0
# 8879    10         SHOA        EX1  EX1-8      6.0     9.0      9.0
#
# [8809 rows x 7 columns]>
#       Page       Imagen Experiment   Code  Valence  Domain  Arousal
# 0        1  Carabineros        EX2  EX2-1      1.0     9.0      5.0
# 1        1  Carabineros        EX2  EX2-2      3.0     8.0      8.0
# 3        1  Carabineros        EX2  EX2-4      1.0     9.0      8.0
# 4        1  Carabineros        EX2  EX2-5      1.0     9.0      8.0
# 5        1  Carabineros        EX2  EX2-6      5.0     5.0      5.0
# ...    ...          ...        ...    ...      ...     ...      ...
# 8875    10         SHOA        EX1  EX1-4      5.0     9.0      9.0
# 8876    10         SHOA        EX1  EX1-5      6.0     9.0      9.0
# 8877    10         SHOA        EX1  EX1-6      3.0     7.0      7.0
# 8878    10         SHOA        EX1  EX1-7      4.0     7.0      8.0
# 8879    10         SHOA        EX1  EX1-8      6.0     9.0      9.0
#
# [8809 rows x 7 columns]

# %%
#Eliminación de columnas irrelevantes
df.drop('Experiment', axis = 'columns', inplace = True)
df.drop('Imagen', axis = 'columns', inplace = True)
df.drop('Code', axis = 'columns', inplace = True)

# %% [markdown]
# #### Transformación de datos

# %%
df['Domain'] = df['Domain'].astype('int64')
df['Arousal'] = df['Arousal'].astype('int64')
df['Valence'] = df['Valence'].astype('int64')
print(df.dtypes)
df
# Out:
# Page       int64
# Valence    int64
# Domain     int64
# Arousal    int64
# dtype: object
#       Page  Valence  Domain  Arousal
# 0        1        1       9        5
# 1        1        3       8        8
# 3        1        1       9        8
# 4        1        1       9        8
# 5        1        5       5        5
# ...    ...      ...     ...      ...
# 8875    10        5       9        9
# 8876    10        6       9        9
# 8877    10        3       7        7
# 8878    10        4       7        8
# 8879    10        6       9        9
#
# [8809 rows x 4 columns]

# %%
scaler = preprocessing.MinMaxScaler()
X = df.drop('Page', axis=1)
names = X.columns
d = scaler.fit_transform(X)
scaled_df = pd.DataFrame(d, columns=names)
scaled_df.head()
# Out:
#    Valence  Domain  Arousal
# 0     0.00   1.000    0.500
# 1     0.25   0.875    0.875
# 2     0.00   1.000    0.875
# 3     0.00   1.000    0.875
# 4     0.50   0.500    0.500

# %% [markdown]
# ### **Entrenamiento del modelo**

# %%
X = scaled_df
Y = df['Page']
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.3,random_state=0, stratify= Y)
X_train
# Out:
#       Valence  Domain  Arousal
# 3810    1.000   0.000    0.000
# 3437    1.000   0.750    0.500
# 5702    0.375   0.500    0.750
# 7388    0.000   0.375    0.125
# 2021    0.500   1.000    1.000
# ...       ...     ...      ...
# 3283    1.000   0.500    0.375
# 4307    0.875   0.500    0.500
# 3825    0.625   0.000    0.000
# 7030    0.000   0.500    0.375
# 3177    0.750   0.125    0.250
#
# [6166 rows x 3 columns]

# %% [markdown]
# ### **SVM**

# %% [markdown]
# #### **RBF**

# %% [markdown]
# ##### *ONE VS ONE*

# %%
rbf1 = SVC(kernel='rbf', C = 10, gamma = 10, probability=True, max_iter=1000)
ovo1 = OneVsOneClassifier(rbf1)
ovo1.fit(X_train,Y_train)
Y_pred_ovo1=ovo1.predict(X_test)
print(f"El modelo tiene una precisión del {round(precision_score(Y_test, Y_pred_ovo1, average='weighted')*100,2)}%")
print(f"El modelo tiene un accuracy del {round(accuracy_score(Y_pred_ovo1,Y_test)*100,2)}%")
print(f"El modelo tiene un f1 de {round(f1_score(Y_test, Y_pred_ovo1, average='weighted')*100,2)}%")
# Out:
# El modelo tiene una precisión del 71.87%
# El modelo tiene un accuracy del 71.06%
# El modelo tiene un f1 de 71.3%

# %%
cfm = confusion_matrix(Y_test, Y_pred_ovo1)
ax = sns.heatmap(cfm, annot=True, fmt="", linewidths=0.7,linecolor="white",
            annot_kws = {'size': 10},cmap=sns.cubehelix_palette(as_cmap=True),
            xticklabels=['Carabineros','Ejercito','InCancer','Junaeb','Medioambiente','Parquemet','PDI','Sernac','Serviu','SHOA'],
            yticklabels=['Carabineros','Ejercito','InCancer','Junaeb','Medioambiente','Parquemet','PDI','Sernac','Serviu','SHOA'],)
font = {'family': 'arial','color':  'black','weight': 'normal','size': 13,}
ax.set_xlabel('\n Etiqueta clasificada')
ax.set_ylabel('Etiqueta actual')
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)
plt.xticks(rotation=0)
plt.rcParams["figure.figsize"]=(12,5)

# %%
from sklearn.metrics import classification_report
Resultados = classification_report(Y_test, Y_pred_ovo1)
print(Resultados)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.57      0.65      0.61       265
#            2       0.68      0.67      0.68       264
#            3       0.76      0.73      0.75       265
#            4       0.90      0.82      0.86       265
#            5       0.67      0.69      0.68       264
#            6       0.80      0.86      0.83       264
#            7       0.65      0.61      0.63       262
#            8       0.55      0.64      0.59       265
#            9       0.87      0.72      0.79       265
#           10       0.72      0.71      0.71       264
#
#     accuracy                           0.71      2643
#    macro avg       0.72      0.71      0.71      2643
# weighted avg       0.72      0.71      0.71      2643

# %% [markdown]
# ##### *ONE VS ALL*

# %%
rbf2 = SVC(kernel='rbf', C = 10, gamma = 10, probability=True, max_iter=1000)
ovo2 = OneVsRestClassifier(rbf2)
ovo2.fit(X_train,Y_train)
Y_pred_ovo2=ovo2.predict(X_test)
print(f"El modelo tiene una precisión del {round(precision_score(Y_test, Y_pred_ovo2, average='weighted')*100,2)}%")
print(f"El modelo tiene un accuracy del {round(accuracy_score(Y_pred_ovo2,Y_test)*100,2)}%")
print(f"El modelo tiene un f1 de {round(f1_score(Y_test, Y_pred_ovo2, average='weighted')*100,2)}%")
# Out:
# El modelo tiene una precisión del 71.43%
# El modelo tiene un accuracy del 68.63%
# El modelo tiene un f1 de 68.54%

# %%
cfm = confusion_matrix(Y_test, Y_pred_ovo2)
ax = sns.heatmap(cfm, annot=True, fmt="", linewidths=0.7,linecolor="white",
            annot_kws = {'size': 10},cmap=sns.cubehelix_palette(as_cmap=True),
            xticklabels=['Carabineros','Ejercito','InCancer','Junaeb','Medioambiente','Parquemet','PDI','Sernac','Serviu','SHOA'],
            yticklabels=['Carabineros','Ejercito','InCancer','Junaeb','Medioambiente','Parquemet','PDI','Sernac','Serviu','SHOA'],)
font = {'family': 'arial','color':  'black','weight': 'normal','size': 13,}
ax.set_xlabel('\n Etiqueta clasificada')
ax.set_ylabel('Etiqueta actual')
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)
plt.xticks(rotation=0)
plt.rcParams["figure.figsize"]=(12,5)

# %%
from sklearn.metrics import classification_report
Resultados = classification_report(Y_test, Y_pred_ovo2)
print(Resultados)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.57      0.66      0.61       265
#            2       0.52      0.72      0.60       264
#            3       0.76      0.74      0.75       265
#            4       0.89      0.82      0.86       265
#            5       0.67      0.70      0.69       264
#            6       0.81      0.86      0.83       264
#            7       0.80      0.49      0.61       262
#            8       0.77      0.38      0.51       265
#            9       0.83      0.74      0.78       265
#           10       0.51      0.75      0.61       264
#
#     accuracy                           0.69      2643
#    macro avg       0.71      0.69      0.69      2643
# weighted avg       0.71      0.69      0.69      2643

# %% [markdown]
# #### **LINEAL**

# %% [markdown]
# ##### *ONE VS ONE*

# %%
lineal1 = SVC(kernel='linear', C = 100, probability=True, max_iter=5000)
ovo5 = OneVsOneClassifier(lineal1)
ovo5.fit(X_train,Y_train)
Y_pred_ovo5=ovo5.predict(X_test)
print(f"El modelo tiene una precisión del {round(precision_score(Y_test, Y_pred_ovo5, average='weighted')*100,2)}%")
print(f"El modelo tiene un accuracy del {round(accuracy_score(Y_pred_ovo5,Y_test)*100,2)}%")
print(f"El modelo tiene un f1 de {round(f1_score(Y_test, Y_pred_ovo5, average='weighted')*100,2)}%")
# Out:
# El modelo tiene una precisión del 61.41%
# El modelo tiene un accuracy del 59.82%
# El modelo tiene un f1 de 59.9%

# %%
cfm = confusion_matrix(Y_test, Y_pred_ovo5)
ax = sns.heatmap(cfm, annot=True, fmt="", linewidths=0.7,linecolor="white",
            annot_kws = {'size': 10},cmap=sns.cubehelix_palette(as_cmap=True),
            xticklabels=['Carabineros','Ejercito','InCancer','Junaeb','Medioambiente','Parquemet','PDI','Sernac','Serviu','SHOA'],
            yticklabels=['Carabineros','Ejercito','InCancer','Junaeb','Medioambiente','Parquemet','PDI','Sernac','Serviu','SHOA'],)
font = {'family': 'arial','color':  'black','weight': 'normal','size': 13,}
ax.set_xlabel('\n Etiqueta clasificada')
ax.set_ylabel('Etiqueta actual')
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)
plt.xticks(rotation=0)
plt.rcParams["figure.figsize"]=(12,5)

# %%
from sklearn.metrics import classification_report
Resultados = classification_report(Y_test, Y_pred_ovo5)
print(Resultados)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.64      0.45      0.53       265
#            2       0.40      0.61      0.48       264
#            3       0.61      0.61      0.61       265
#            4       0.84      0.76      0.80       265
#            5       0.54      0.58      0.56       264
#            6       0.79      0.75      0.77       264
#            7       0.67      0.60      0.63       262
#            8       0.36      0.37      0.36       265
#            9       0.68      0.84      0.75       265
#           10       0.62      0.41      0.49       264
#
#     accuracy                           0.60      2643
#    macro avg       0.61      0.60      0.60      2643
# weighted avg       0.61      0.60      0.60      2643

# %% [markdown]
# ##### *ONE VS ALL*

# %%
lineal2 = SVC(kernel='linear', C = 100, probability=True, max_iter=5000)
ovo6 = OneVsRestClassifier(lineal2)
ovo6.fit(X_train,Y_train)
Y_pred_ovo6=ovo6.predict(X_test)
print(f"El modelo tiene una precisión del {round(precision_score(Y_test, Y_pred_ovo6, average='weighted')*100,2)}%")
print(f"El modelo tiene un accuracy del {round(accuracy_score(Y_pred_ovo6,Y_test)*100,2)}%")
print(f"El modelo tiene un f1 de {round(f1_score(Y_test, Y_pred_ovo6, average='weighted')*100,2)}%")
# Out:
# El modelo tiene una precisión del 24.13%
# El modelo tiene un accuracy del 31.63%
# El modelo tiene un f1 de 25.96%

# %%
cfm = confusion_matrix(Y_test, Y_pred_ovo6)
ax = sns.heatmap(cfm, annot=True, fmt="", linewidths=0.7,linecolor="white",
            annot_kws = {'size': 10},cmap=sns.cubehelix_palette(as_cmap=True),
            xticklabels=['Carabineros','Ejercito','InCancer','Junaeb','Medioambiente','Parquemet','PDI','Sernac','Serviu','SHOA'],
            yticklabels=['Carabineros','Ejercito','InCancer','Junaeb','Medioambiente','Parquemet','PDI','Sernac','Serviu','SHOA'],)
font = {'family': 'arial','color':  'black','weight': 'normal','size': 13,}
ax.set_xlabel('\n Etiqueta clasificada')
ax.set_ylabel('Etiqueta actual')
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)
plt.xticks(rotation=0)
plt.rcParams["figure.figsize"]=(12,5)

# %%
from sklearn.metrics import classification_report
Resultados = classification_report(Y_test, Y_pred_ovo6)
print(Resultados)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.23      0.64      0.33       265
#            2       0.67      0.48      0.56       264
#            3       0.06      0.03      0.04       265
#            4       0.61      0.77      0.68       265
#            5       0.42      0.45      0.44       264
#            6       0.31      0.64      0.41       264
#            7       0.00      0.00      0.00       262
#            8       0.00      0.00      0.00       265
#            9       0.12      0.15      0.13       265
#           10       0.00      0.00      0.00       264
#
#     accuracy                           0.32      2643
#    macro avg       0.24      0.32      0.26      2643
# weighted avg       0.24      0.32      0.26      2643

# %% [markdown]
# #### **POLINOMIAL**

# %% [markdown]
# ##### *ONE VS ONE*

# %%
poly1 = SVC(kernel='poly', C = 10, gamma = 1, probability=True, degree= 3, max_iter=3000)
ovo3 = OneVsOneClassifier(poly1)
ovo3.fit(X_train,Y_train)
Y_pred_ovo3=ovo3.predict(X_test)
print(f"El modelo tiene una precisión del {round(precision_score(Y_test, Y_pred_ovo3, average='weighted')*100,2)}%")
print(f"El modelo tiene un accuracy del {round(accuracy_score(Y_pred_ovo3,Y_test)*100,2)}%")
print(f"El modelo tiene un f1 de {round(f1_score(Y_test, Y_pred_ovo3, average='weighted')*100,2)}%")
# Out:
# El modelo tiene una precisión del 67.18%
# El modelo tiene un accuracy del 63.26%
# El modelo tiene un f1 de 62.98%

# %%
cfm = confusion_matrix(Y_test, Y_pred_ovo3)
ax = sns.heatmap(cfm, annot=True, fmt="", linewidths=0.7,linecolor="white",
            annot_kws = {'size': 10},cmap=sns.cubehelix_palette(as_cmap=True),
            xticklabels=['Carabineros','Ejercito','InCancer','Junaeb','Medioambiente','Parquemet','PDI','Sernac','Serviu','SHOA'],
            yticklabels=['Carabineros','Ejercito','InCancer','Junaeb','Medioambiente','Parquemet','PDI','Sernac','Serviu','SHOA'],)
font = {'family': 'arial','color':  'black','weight': 'normal','size': 13,}
ax.set_xlabel('\n Etiqueta clasificada')
ax.set_ylabel('Etiqueta actual')
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)
plt.xticks(rotation=0)
plt.rcParams["figure.figsize"]=(12,5)

# %%
from sklearn.metrics import classification_report
Resultados = classification_report(Y_test, Y_pred_ovo3)
print(Resultados)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.75      0.38      0.51       265
#            2       0.72      0.54      0.62       264
#            3       0.74      0.66      0.70       265
#            4       0.90      0.77      0.83       265
#            5       0.66      0.51      0.58       264
#            6       0.57      0.89      0.70       264
#            7       0.79      0.50      0.61       262
#            8       0.42      0.74      0.54       265
#            9       0.58      0.83      0.69       265
#           10       0.58      0.48      0.53       264
#
#     accuracy                           0.63      2643
#    macro avg       0.67      0.63      0.63      2643
# weighted avg       0.67      0.63      0.63      2643

# %% [markdown]
# ##### *ONE VS ALL*

# %%
poly2 = SVC(kernel='poly', C = 100, gamma=1, probability=True, degree=3)
ovo4 = OneVsRestClassifier(poly2)
ovo4.fit(X_train,Y_train)
Y_pred_ovo4=ovo4.predict(X_test)
print(f"El modelo tiene una precisión del {round(precision_score(Y_test, Y_pred_ovo4, average='weighted')*100,2)}%")
print(f"El modelo tiene un accuracy del {round(accuracy_score(Y_pred_ovo4,Y_test)*100,2)}%")
print(f"El modelo tiene un f1 de {round(f1_score(Y_test, Y_pred_ovo4, average='weighted')*100,2)}%")
# Out:
# El modelo tiene una precisión del 54.15%
# El modelo tiene un accuracy del 53.69%
# El modelo tiene un f1 de 51.82%

# %%
cfm = confusion_matrix(Y_test, Y_pred_ovo4)
ax = sns.heatmap(cfm, annot=True, fmt="", linewidths=0.7,linecolor="white",
            annot_kws = {'size': 10},cmap=sns.cubehelix_palette(as_cmap=True),
            xticklabels=['Carabineros','Ejercito','InCancer','Junaeb','Medioambiente','Parquemet','PDI','Sernac','Serviu','SHOA'],
            yticklabels=['Carabineros','Ejercito','InCancer','Junaeb','Medioambiente','Parquemet','PDI','Sernac','Serviu','SHOA'],)
font = {'family': 'arial','color':  'black','weight': 'normal','size': 13,}
ax.set_xlabel('\n Etiqueta clasificada')
ax.set_ylabel('Etiqueta actual')
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)
plt.xticks(rotation=0)
plt.rcParams["figure.figsize"]=(12,5)

# %%
from sklearn.metrics import classification_report
Resultados = classification_report(Y_test, Y_pred_ovo4)
print(Resultados)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.73      0.24      0.36       265
#            2       0.37      0.67      0.48       264
#            3       0.52      0.59      0.55       265
#            4       0.83      0.77      0.80       265
#            5       0.56      0.47      0.51       264
#            6       0.69      0.76      0.72       264
#            7       0.55      0.65      0.60       262
#            8       0.41      0.27      0.33       265
#            9       0.65      0.86      0.74       265
#           10       0.11      0.08      0.09       264
#
#     accuracy                           0.54      2643
#    macro avg       0.54      0.54      0.52      2643
# weighted avg       0.54      0.54      0.52      2643
